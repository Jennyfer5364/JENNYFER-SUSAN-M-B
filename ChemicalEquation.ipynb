# %% [markdown]
# Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %% [markdown]
# Required packages to import and display images

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# Reading and displaying the image

# %% [markdown]
# importing single image from the drive

# %%
img = cv2.imread('/content/drive/MyDrive/gasdispersion.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=192x256 at 0x7FA2AB89A590>

# %% [markdown]
# Importing the images from local system

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-f1deb860-1dec-45cd-9cbe-1318ad6f0e2b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f1deb860-1dec-45cd-9cbe-1318ad6f0e2b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving gasdispersion.jpg to gasdispersion.jpg
# User uploaded file "gasdispersion.jpg" with length 25858 bytes

# %% [markdown]
# Exatacting the zip file

# %%
import zipfile
from google.colab import drive
zip_ref = zipfile.ZipFile('/gdrive/MyDrive/Pretrained BubbleNet and Bubble Image Database.zip', 'r')
zip_ref.extractall('/gdrive/MyDrive/extracted_Bubble_Files')

# %% [markdown]
# Reading multiple images

# %%
from os import listdir
from os.path import isfile, join
import numpy
import cv2
mypath='/gdrive/MyDrive/extracted_Bubble_Files/Testing dataset/Class 1'
onlyfiles = [ f for f in listdir(mypath) if isfile(join(mypath,f)) ]
images = numpy.empty(len(onlyfiles), dtype=object)
for n in range(0, len(onlyfiles)):
  images[n] = cv2.imread( join(mypath,onlyfiles[n]) )

# %% [markdown]
# Displaying multiple images

# %%
from io import BytesIO
import PIL
from IPython.display import display, Image

def display_img_array(ima):
    im = PIL.Image.fromarray(ima)
    bio = BytesIO()
    im.save(bio, format='png')
    display(Image(bio.getvalue(), format='png'))

for ima in images:
    display_img_array(ima)

# %% [markdown]
# Gaussian Blur

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy
img = cv2.imread('/content/drive/MyDrive/extracted_Bubble_Files/Testing dataset/Class 1/13863.jpg')
dst = cv2.GaussianBlur(img,(3,3),cv2.BORDER_DEFAULT) 
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=192x256 at 0x7FA2AB8768D0>
